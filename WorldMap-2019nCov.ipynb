# %%
import pandas as pd
import pyecharts
import pyecharts.options as opts
from pyecharts.charts import Map

world_data = pd.read_csv('./DataSet/today_world_2021_04_12.csv')
#各国家的 累计确诊人数---累计治愈----累计死亡人数===现存确诊人数
world_data['today_storeConfirm'] = world_data['total_confirm'] - world_data['total_heal'] - world_data['total_dead']
contry_name = pd.read_csv('./DataSet/county_china_english.csv', encoding='GB2312')
world_data['eg_name'] = world_data['name'].replace(contry_name['中文'].values ,contry_name['英文'].values)
heatmap_data = world_data[['eg_name','today_storeConfirm']].values.tolist()
#绘图
map_test = Map().add(series_name = "现存确诊人数",
                 data_pair = heatmap_data, 
                 maptype = "world",
                 is_map_symbol_show = False
                )
map_test.set_series_opts(label_opts=opts.LabelOpts(is_show=False))  # 不显示国家（标签）名称 
# 设置全局配置项
map_test.set_global_opts(title_opts = opts.TitleOpts(title="世界各国家现存确诊人数地图 截止：2021.4.12"), # 设置图标题
                     # 设置视觉映射配置项
                     visualmap_opts = opts.VisualMapOpts(pieces=[ # 自定义分组的分点和颜色
                                                               {"min": 10000,"color":"#800000"}, # 栗色
                                                               {"min": 5000, "max": 9999, "color":"#B22222"}, # 耐火砖
                                                               {"min": 999, "max": 4999,"color":"#CD5C5C"}, # 印度红
                                                               {"min": 100, "max": 999, "color":"#BC8F8F"}, # 玫瑰棕色
                                                               {"max": 99, "color":"#FFE4E1"}, # 薄雾玫瑰
                                                              ], 
                     is_piecewise = True))  # 显示分段式图例
map_test.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="8673eca0c7954896a13cccfc7bdccf65" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_8673eca0c7954896a13cccfc7bdccf65 = echarts.init(
#                     document.getElementById('8673eca0c7954896a13cccfc7bdccf65'), 'white', {renderer: 'canvas'});
#                 var option_8673eca0c7954896a13cccfc7bdccf65 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u73b0\u5b58\u786e\u8bca\u4eba\u6570",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "Tunisia",
#                     "value": 37661
#                 },
#                 {
#                     "name": "Serbia",
#                     "value": 636473
#                 },
#                 {
#                     "name": "China",
#                     "value": 488
#                 },
#                 {
#                     "name": "\u65e5\u672c\u672c\u571f",
#                     "value": 33299
#                 },
#                 {
#                     "name": "Thailand",
#                     "value": 6640
#                 },
#                 {
#                     "name": "Singapore",
#                     "value": 288
#                 },
#                 {
#                     "name": "Korea",
#                     "value": 7572
#                 },
#                 {
#                     "name": "Australia",
#                     "value": 5425
#                 },
#                 {
#                     "name": "Germany",
#                     "value": 241428
#                 },
#                 {
#                     "name": "United States",
#                     "value": 6862240
#                 },
#                 {
#                     "name": "Malaysia",
#                     "value": 15574
#                 },
#                 {
#                     "name": "Vietnam",
#                     "value": 229
#                 },
#                 {
#                     "name": "Saint Barthelemy",
#                     "value": 0
#                 },
#                 {
#                     "name": "Kenya",
#                     "value": 44227
#                 },
#                 {
#                     "name": "Iran",
#                     "value": 294677
#                 },
#                 {
#                     "name": "Israel",
#                     "value": 3484
#                 },
#                 {
#                     "name": "\u6bdb\u5229\u4e9a\u5c3c\u4e9a",
#                     "value": 8
#                 },
#                 {
#                     "name": "Lebanon",
#                     "value": 88013
#                 },
#                 {
#                     "name": "Croatia",
#                     "value": 13241
#                 },
#                 {
#                     "name": "Austria",
#                     "value": 31522
#                 },
#                 {
#                     "name": "Switzerland",
#                     "value": 289490
#                 },
#                 {
#                     "name": "Greece",
#                     "value": 192831
#                 },
#                 {
#                     "name": "Mauritius",
#                     "value": 405
#                 },
#                 {
#                     "name": "Estonia",
#                     "value": 18339
#                 },
#                 {
#                     "name": "Macedonia",
#                     "value": 20836
#                 },
#                 {
#                     "name": "Belarus",
#                     "value": 7197
#                 },
#                 {
#                     "name": "Lithuania",
#                     "value": 17121
#                 },
#                 {
#                     "name": "Azerbaijan",
#                     "value": 31370
#                 },
#                 {
#                     "name": "U.S. Virgin Islands",
#                     "value": 20
#                 },
#                 {
#                     "name": "Mongolia",
#                     "value": 99
#                 },
#                 {
#                     "name": "Ukraine",
#                     "value": 409517
#                 },
#                 {
#                     "name": "Poland",
#                     "value": 344909
#                 },
#                 {
#                     "name": "Bosnia and Herz.",
#                     "value": 35210
#                 },
#                 {
#                     "name": "Montserrat",
#                     "value": 0
#                 },
#                 {
#                     "name": "South Africa",
#                     "value": 21840
#                 },
#                 {
#                     "name": "Burundi",
#                     "value": 39
#                 },
#                 {
#                     "name": "South Sudan",
#                     "value": 1667
#                 },
#                 {
#                     "name": "Malta",
#                     "value": 558
#                 },
#                 {
#                     "name": "Moldova",
#                     "value": 12902
#                 },
#                 {
#                     "name": "Bulgaria",
#                     "value": 71317
#                 },
#                 {
#                     "name": "\u5b5f\u52a0\u62c9",
#                     "value": 98427
#                 },
#                 {
#                     "name": "Albania",
#                     "value": 441
#                 },
#                 {
#                     "name": "State of Palestine",
#                     "value": 32312
#                 },
#                 {
#                     "name": "Comoros",
#                     "value": 60
#                 },
#                 {
#                     "name": "Afghanistan",
#                     "value": 2650
#                 },
#                 {
#                     "name": "Saudi Arabia",
#                     "value": 8360
#                 },
#                 {
#                     "name": "New Zealand",
#                     "value": 100
#                 },
#                 {
#                     "name": "Tajikistan",
#                     "value": 0
#                 },
#                 {
#                     "name": "Jersey",
#                     "value": 6
#                 },
#                 {
#                     "name": "Syria",
#                     "value": 97
#                 },
#                 {
#                     "name": "Panama",
#                     "value": 4217
#                 },
#                 {
#                     "name": "Cuba",
#                     "value": 5267
#                 },
#                 {
#                     "name": "Nigeria",
#                     "value": 7632
#                 },
#                 {
#                     "name": "Morocco",
#                     "value": 4841
#                 },
#                 {
#                     "name": "Senegal",
#                     "value": 179
#                 },
#                 {
#                     "name": "Lao PDR",
#                     "value": 0
#                 },
#                 {
#                     "name": "Bahamas",

# %%
#map_test.render('map_world_test.html') #保存成本地的的参数设置
